# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,plot_roc_curve,plot_precision_recall_curve
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier



from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.gaussian_process.kernels import RBF

from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import  AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.linear_model import SGDClassifier
import seaborn as sns

# %%
dataset = pd.read_csv("churn-bigml-80.csv")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2666 entries, 0 to 2665
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   2666 non-null   object
#  1   Account length          2666 non-null   int64
#  2   Area code               2666 non-null   int64
#  3   International plan      2666 non-null   object
#  4   Voice mail plan         2666 non-null   object
#  5   Number vmail messages   2666 non-null   int64
#  6   Total day minutes       2666 non-null   float64
#  7   Total day calls         2666 non-null   int64
#  8   Total day charge        2666 non-null   float64
#  9   Total eve minutes       2666 non-null   float64
#  10  Total eve calls         2666 non-null   int64
#  11  Total eve charge        2666 non-null   float64
#  12  Total night minutes     2666 non-null   float64
#  13  Total night calls       2666 non-null   int64
#  14  Total night charge      2666 non-null   float64
#  15  Total intl minutes      2666 non-null   float64
#  16  Total intl calls        2666 non-null   int64
#  17  Total intl charge       2666 non-null   float64
#  18  Customer service calls  2666 non-null   int64
#  19  Churn                   2666 non-null   bool
# dtypes: bool(1), float64(8), int64(8), object(3)
# memory usage: 398.5+ KB

# %%
dataset.head(5)
# Out:
#   State  Account length  ...  Customer service calls  Churn
# 0    KS             128  ...                       1  False
# 1    OH             107  ...                       1  False
# 2    NJ             137  ...                       0  False
# 3    OH              84  ...                       2  False
# 4    OK              75  ...                       3  False
#
# [5 rows x 20 columns]

# %%
dataset.shape
# Out:
# (2666, 20)

# %%
missing_data=dataset.isnull()
for column in missing_data.columns.values.tolist():
    print(column)
    print(missing_data[column].value_counts())
    print("")
# Looking at data types
dataset.dtypes
# Out:
# State
# False    2666
# Name: State, dtype: int64
#
# Account length
# False    2666
# Name: Account length, dtype: int64
#
# Area code
# False    2666
# Name: Area code, dtype: int64
#
# International plan
# False    2666
# Name: International plan, dtype: int64
#
# Voice mail plan
# False    2666
# Name: Voice mail plan, dtype: int64
#
# Number vmail messages
# False    2666
# Name: Number vmail messages, dtype: int64
#
# Total day minutes
# False    2666
# Name: Total day minutes, dtype: int64
#
# Total day calls
# False    2666
# Name: Total day calls, dtype: int64
#
# Total day charge
# False    2666
# Name: Total day charge, dtype: int64
#
# Total eve minutes
# False    2666
# Name: Total eve minutes, dtype: int64
#
# Total eve calls
# False    2666
# Name: Total eve calls, dtype: int64
#
# Total eve charge
# False    2666
# Name: Total eve charge, dtype: int64
#
# Total night minutes
# False    2666
# Name: Total night minutes, dtype: int64
#
# Total night calls
# False    2666
# Name: Total night calls, dtype: int64
#
# Total night charge
# False    2666
# Name: Total night charge, dtype: int64
#
# Total intl minutes
# False    2666
# Name: Total intl minutes, dtype: int64
#
# Total intl calls
# False    2666
# Name: Total intl calls, dtype: int64
#
# Total intl charge
# False    2666
# Name: Total intl charge, dtype: int64
#
# Customer service calls
# False    2666
# Name: Customer service calls, dtype: int64
#
# Churn
# False    2666
# Name: Churn, dtype: int64
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                        bool
# dtype: object

# %%
dataset.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
dummy = pd.get_dummies(dataset['Voice mail plan'])
data = pd.concat((dataset,dummy),axis=1)
data =data.drop(['Voice mail plan'],axis=1)
data =data.rename(columns={"Yes":"Voice mail plan"})
dummy2 = pd.get_dummies(data['International plan'])
set1 = pd.concat((data,dummy2),axis=1)
set1 =set1.drop(['No'],axis=1)
set1 =set1.drop(['International plan'],axis=1)
set1 =set1.rename(columns={"Yes":"International plan"})
try:
  set1['international voice call usage'] = set1['Total intl calls'] / set1['Total intl minutes']
  
  
  set1['international voice call usage'] = set1['international voice call usage'] * set1['Total intl charge']

except ZeroDivisionError:
  print ("division by zero")
set1.head()
# Out:
#   State  Account length  ...  International plan  international voice call usage
# 0    KS             128  ...                   0                        0.810000
# 1    OH             107  ...                   0                        0.810219
# 2    NJ             137  ...                   0                        1.348361
# 3    OH              84  ...                   1                        1.887879
# 4    OK              75  ...                   1                        0.810891
#
# [5 rows x 21 columns]

# %%
set1 =set1.drop(['Total intl charge','Total intl calls','Total intl minutes'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-e8ed21ebaa28> in <module>()
# ----> 1 set1 =set1.drop(['Total intl charge','Total intl calls','Total intl minutes'],axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3921                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3922             else:
# -> 3923                 new_axis = axis.drop(labels, errors=errors)
#    3924             result = self.reindex(**{axis_name: new_axis})
#    3925
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5285         if mask.any():
#    5286             if errors != "ignore":
# -> 5287                 raise KeyError(f"{labels[mask]} not found in axis")
#    5288             indexer = indexer[~mask]
#    5289         return self.delete(indexer)
#
# KeyError: "['Total intl charge' 'Total intl calls' 'Total intl minutes'] not found in axis"

# %%
set1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2666 entries, 0 to 2665
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   State                           2666 non-null   object
#  1   Account length                  2666 non-null   int64
#  2   Area code                       2666 non-null   int64
#  3   Number vmail messages           2666 non-null   int64
#  4   Total day minutes               2666 non-null   float64
#  5   Total day calls                 2666 non-null   int64
#  6   Total day charge                2666 non-null   float64
#  7   Total eve minutes               2666 non-null   float64
#  8   Total eve calls                 2666 non-null   int64
#  9   Total eve charge                2666 non-null   float64
#  10  Total night minutes             2666 non-null   float64
#  11  Total night calls               2666 non-null   int64
#  12  Total night charge              2666 non-null   float64
#  13  Customer service calls          2666 non-null   int64
#  14  Churn                           2666 non-null   bool
#  15  Voice mail plan                 2666 non-null   uint8
#  16  International plan              2666 non-null   uint8
#  17  international voice call usage  2651 non-null   float64
# dtypes: bool(1), float64(7), int64(7), object(1), uint8(2)
# memory usage: 320.4+ KB

# %%
set1.describe()
# Out:
#        Account length  ...  international voice call usage
# count     2666.000000  ...                     2651.000000
# mean       100.620405  ...                        1.213264
# std         39.563974  ...                        0.658939
# min          1.000000  ...                        0.269048
# 25%         73.000000  ...                        0.809524
# 50%        100.000000  ...                        1.080460
# 75%        127.000000  ...                        1.618310
# max        243.000000  ...                        5.395683
#
# [8 rows x 16 columns]

# %%
col_name="Churn"
first_col = set1.pop(col_name)

# %%
set1.insert(17, col_name, first_col)

# %%
set1.head()
# Out:
#   State  Account length  ...  international voice call usage  Churn
# 0    KS             128  ...                        0.810000  False
# 1    OH             107  ...                        0.810219  False
# 2    NJ             137  ...                        1.348361  False
# 3    OH              84  ...                        1.887879  False
# 4    OK              75  ...                        0.810891  False
#
# [5 rows x 18 columns]

# %%
set1['international voice call usage'] = set1['international voice call usage'].replace(np.nan, 0)

# %%
set1['Churn'].unique()
# Out:
# array([False,  True])

# %%
X = set1.iloc[:,1:17].values
yy  = set1.iloc[:,1:17]
Y= set1.iloc[:,17].values

# %%
for col in yy.columns: 
    try:      
        yy[col] = pd.to_numeric(yy[col]) 
        yy.hist(column=col)
    except ValueError:
        print('This column can not be represented as a histogram')

# %%
Y
# Out:
# array([False, False, False, ..., False, False, False])

# %%
X
# Out:
# array([[128.        , 415.        ,  25.        , ...,   1.        ,
#           0.        ,   0.81      ],
#        [107.        , 415.        ,  26.        , ...,   1.        ,
#           0.        ,   0.81021898],
#        [137.        , 415.        ,   0.        , ...,   0.        ,
#           0.        ,   1.34836066],
#        ...,
#        [ 68.        , 415.        ,   0.        , ...,   0.        ,
#           0.        ,   1.07916667],
#        [ 28.        , 510.        ,   0.        , ...,   0.        ,
#           0.        ,   1.6212766 ],
#        [ 74.        , 415.        ,  25.        , ...,   1.        ,
#           0.        ,   1.08029197]])

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
sc = StandardScaler()
x_train= sc.fit_transform(x_train)

# %%
x_test= sc.transform(x_test)

# %%
clf = RandomForestClassifier(n_estimators=30)
clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=30,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_pred = clf.predict(x_test)

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[464,   1],
#        [ 23,  46]])

# %%
classification_report(y_test,y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n       False       0.95      1.00      0.97       465\n        True       0.98      0.62      0.76        69\n\n    accuracy                           0.95       534\n   macro avg       0.96      0.81      0.87       534\nweighted avg       0.95      0.95      0.94       534\n'

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.949438202247191

# %%
importances= clf.feature_importances_
for i,v in enumerate(importances):
	print('Feature: %0d, Score: %.5f' % (i,v))

# visualize to see the feature importance
indices=np.argsort(importances)[::-1]
plt.figure(figsize=(20,10))

plt.bar( range(len(clf.feature_importances_)), clf.feature_importances_)
plt.xticks(range(len(clf.feature_importances_)), yy.columns)
plt.show()
# Out:
# Feature: 0, Score: 0.04029
# Feature: 1, Score: 0.01167
# Feature: 2, Score: 0.03658
# Feature: 3, Score: 0.14819
# Feature: 4, Score: 0.03828
# Feature: 5, Score: 0.12304
# Feature: 6, Score: 0.07274
# Feature: 7, Score: 0.03456
# Feature: 8, Score: 0.07623
# Feature: 9, Score: 0.05271
# Feature: 10, Score: 0.03755
# Feature: 11, Score: 0.04836
# Feature: 12, Score: 0.11924
# Feature: 13, Score: 0.01888
# Feature: 14, Score: 0.07527
# Feature: 15, Score: 0.06642

# %%
names = ["Nearest_Neighbors","RandomForestClassifier","DecisionTreeClassifier", "Linear_SVM", "Polynomial_SVM", "RBF_SVM", "Gaussian_Process",
         "Gradient_Boosting", "Extra_Trees", "Neural_Net", "AdaBoost",
         "Naive_Bayes", "QDA", "SGD"]

classifiers = [
    KNeighborsClassifier(3),
    RandomForestClassifier(n_estimators=20),
    DecisionTreeClassifier(),
    SVC(kernel="linear", C=0.025),
    SVC(kernel="poly", degree=3, C=0.025),
    SVC(kernel="rbf", C=1, gamma=2),
    GaussianProcessClassifier(1.0 * RBF(1.0)),
    GradientBoostingClassifier(n_estimators=100, learning_rate=1.0),
    
    ExtraTreesClassifier(n_estimators=10, min_samples_split=2),
    
    MLPClassifier(alpha=1, max_iter=1000),
    AdaBoostClassifier(n_estimators=100),
    GaussianNB(),
    QuadraticDiscriminantAnalysis(),
    SGDClassifier(loss="hinge", penalty="l2")]

# %%
scores = []
y_pred_dts = []
for name, clf in zip(names, classifiers):
    clf.fit(x_train, y_train)
    score = clf.score(x_test, y_test)
    y_pred_dt= clf.predict(x_test)
    scores.append(score)
    y_pred_dts.append(y_pred_dt)

# %%
matrix1 = []
for name, clf,y_pred1 in zip(names, classifiers,y_pred_dts):
  matrix = confusion_matrix(y_test,y_pred1)
  matrix1.append(matrix)

# %%
df = pd.DataFrame()
df['name'] = names
df['score'] = scores
df[' confusion matrix'] = matrix1
df['percentage']=100*df['score']
df
# Out:
#                       name     score       confusion matrix  percentage
# 0        Nearest_Neighbors  0.889513  [[445, 20], [39, 30]]   88.951311
# 1   RandomForestClassifier  0.956929   [[465, 0], [23, 46]]   95.692884
# 2   DecisionTreeClassifier  0.887640  [[430, 35], [25, 44]]   88.764045
# 3               Linear_SVM  0.870787    [[465, 0], [69, 0]]   87.078652
# 4           Polynomial_SVM  0.870787    [[465, 0], [69, 0]]   87.078652
# 5                  RBF_SVM  0.870787    [[465, 0], [69, 0]]   87.078652
# 6         Gaussian_Process  0.921348   [[457, 8], [34, 35]]   92.134831
# 7        Gradient_Boosting  0.906367  [[440, 25], [25, 44]]   90.636704
# 8              Extra_Trees  0.919476   [[457, 8], [35, 34]]   91.947566
# 9               Neural_Net  0.917603   [[457, 8], [36, 33]]   91.760300
# 10                AdaBoost  0.902622  [[452, 13], [39, 30]]   90.262172
# 11             Naive_Bayes  0.867041  [[425, 40], [31, 38]]   86.704120
# 12                     QDA  0.855805  [[423, 42], [35, 34]]   85.580524
# 13                     SGD  0.865169    [[457, 8], [64, 5]]   86.516854

# %%
cm = sns.light_palette("yellow", as_cmap=True)
s = df.style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
# #T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row0_col1,#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row0_col3{
#             background-color:  #f6f693;
#             color:  #000000;
#         }#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row1_col1,#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row1_col3{
#             background-color:  #ffff00;
#             color:  #000000;
#         }#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row2_col1,#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row2_col3{
#             background-color:  #f6f698;
#             color:  #000000;
#         }#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row3_col1,#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row3_col3,#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row4_col1,#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row4_col3,#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row5_col1,#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row5_col3{
#             background-color:  #f4f4bd;
#             color:  #000000;
#         }#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row6_col1,#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row6_col3{
#             background-color:  #fafa4e;
#             color:  #000000;
#         }#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row7_col1{
#             background-color:  #f9f96e;
#             color:  #000000;
#         }#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row7_col3{
#             background-color:  #f8f86f;
#             color:  #000000;
#         }#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row8_col1,#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row8_col3{
#             background-color:  #fafa52;
#             color:  #000000;
#         }#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row9_col1,#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row9_col3{
#             background-color:  #fafa56;
#             color:  #000000;
#         }#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row10_col1,#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row10_col3{
#             background-color:  #f8f877;
#             color:  #000000;
#         }#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row11_col1,#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row11_col3{
#             background-color:  #f3f3c5;
#             color:  #000000;
#         }#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row12_col1,#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row12_col3{
#             background-color:  #f2f2dd;
#             color:  #000000;
#         }#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row13_col1,#T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row13_col3{
#             background-color:  #f3f3c9;
#             color:  #000000;
#         }</style><table id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >name</th>        <th class="col_heading level0 col1" >score</th>        <th class="col_heading level0 col2" > confusion matrix</th>        <th class="col_heading level0 col3" >percentage</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row0_col0" class="data row0 col0" >Nearest_Neighbors</td>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row0_col1" class="data row0 col1" >0.889513</td>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row0_col2" class="data row0 col2" >[[445  20]
#  [ 39  30]]</td>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row0_col3" class="data row0 col3" >88.951311</td>
#             </tr>
#             <tr>
#                         <th id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row1_col0" class="data row1 col0" >RandomForestClassifier</td>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row1_col1" class="data row1 col1" >0.956929</td>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row1_col2" class="data row1 col2" >[[465   0]
#  [ 23  46]]</td>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row1_col3" class="data row1 col3" >95.692884</td>
#             </tr>
#             <tr>
#                         <th id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row2_col0" class="data row2 col0" >DecisionTreeClassifier</td>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row2_col1" class="data row2 col1" >0.887640</td>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row2_col2" class="data row2 col2" >[[430  35]
#  [ 25  44]]</td>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row2_col3" class="data row2 col3" >88.764045</td>
#             </tr>
#             <tr>
#                         <th id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row3_col0" class="data row3 col0" >Linear_SVM</td>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row3_col1" class="data row3 col1" >0.870787</td>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row3_col2" class="data row3 col2" >[[465   0]
#  [ 69   0]]</td>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row3_col3" class="data row3 col3" >87.078652</td>
#             </tr>
#             <tr>
#                         <th id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row4_col0" class="data row4 col0" >Polynomial_SVM</td>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row4_col1" class="data row4 col1" >0.870787</td>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row4_col2" class="data row4 col2" >[[465   0]
#  [ 69   0]]</td>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row4_col3" class="data row4 col3" >87.078652</td>
#             </tr>
#             <tr>
#                         <th id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row5_col0" class="data row5 col0" >RBF_SVM</td>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row5_col1" class="data row5 col1" >0.870787</td>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row5_col2" class="data row5 col2" >[[465   0]
#  [ 69   0]]</td>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row5_col3" class="data row5 col3" >87.078652</td>
#             </tr>
#             <tr>
#                         <th id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row6_col0" class="data row6 col0" >Gaussian_Process</td>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row6_col1" class="data row6 col1" >0.921348</td>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row6_col2" class="data row6 col2" >[[457   8]
#  [ 34  35]]</td>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row6_col3" class="data row6 col3" >92.134831</td>
#             </tr>
#             <tr>
#                         <th id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row7_col0" class="data row7 col0" >Gradient_Boosting</td>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row7_col1" class="data row7 col1" >0.906367</td>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row7_col2" class="data row7 col2" >[[440  25]
#  [ 25  44]]</td>
#                         <td id="T_5b51f7aa_97ae_11eb_9ff5_0242ac1c0002row

# %%
for name, clf in zip(names, classifiers):
    plot_roc_curve(clf,x_test,y_test)

# %%
sns.set(style="whitegrid")
ax = sns.barplot(y="name", x="score", data=df)

# %%
import matplotlib.pyplot as plotter
figureObject, axesObject = plotter.subplots()
mylabels = df.name
y=df.score
axesObject.axis('equal')
axesObject.pie(y,
        labels = mylabels,
        radius=3,
        
        autopct='%0.1f%%')
plotter.legend(title = "Algorithms scores:",loc='center')
plotter.show()
